# %%
import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Out:
# True

# %%
host = os.getenv('HOST')
username = os.getenv('USER')
password = os.getenv('PASSWORD')

# %%
print(username)
# Out:
# root

# %%
print(password)
# Out:
# 12345678

# %%
connection = mysql.connector.connect(host='localhost',user='root',password='12345678',database='swiftmarket')

# %%
connection.is_connected()
# Out:
# True
